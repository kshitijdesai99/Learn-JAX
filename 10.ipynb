# %% [markdown]
# ## Understanding JAX’s execution environment and memory model

# %% [markdown]
# ### 1–5 → Environment Awareness

# %% [markdown]
# ## ✅ Exercise 1 — Install JAX

# %%
# !pip install jax jaxlib -q
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## ✅ Exercise 2 — Import JAX

# %%
import jax  # CPU only
import jax.numpy as jnp # works on CPU/GPU/TPU

# %% [markdown]
# ## ✅ Exercise 3 — Check Version

# %%
jax.__version__
# Out:
# '0.9.1'

# %% [markdown]
# ## ✅ Exercise 4 — Check Backend

# %%
jax.default_backend() # cpu, gpu, tpu
# Out:
# 'cpu'

# %% [markdown]
# ## ✅ Exercise 5 — Check Devices

# %%
jax.devices()
# Out:
# [CpuDevice(id=0)]

# %% [markdown]
# ### 6–8 → What is a JAX Array?

# %% [markdown]
# ## ✅ Exercise 6 — Create a JAX Array

# %%
data = jnp.array([10, 1, 24]) # A NumPy array that can move to accelerators.
data
# Out:
# Array([10,  1, 24], dtype=int32)

# %% [markdown]
# ## ✅ Exercise 7 — Check Type

# %%
type(data)
# Out:
# jaxlib._jax.ArrayImpl

# %% [markdown]
# ## ✅ Exercise 8 — Check Shape

# %%
data.shape
# Out:
# (3,)

# %% [markdown]
# ## ✅ Exercise 9 — Move Array to Host (CPU Memory)

# %% [markdown]
# ### 9–10 → Host vs Device Memory

# %%
data_host = jax.device_get(data)
data_host
# Out:
# array([10,  1, 24], dtype=int32)

# %% [markdown]
# ## ✅ Exercise 10 — Move Data to Device

# %%
data_device = jax.device_put(data_host)
data_device
# Out:
# Array([10,  1, 24], dtype=int32)
